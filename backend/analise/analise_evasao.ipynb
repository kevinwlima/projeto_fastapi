# %%
import pandas as pd
df = pd.read_csv('../dados/dados_evasao.csv')

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       649 non-null    object
#  1   Age                          649 non-null    int64
#  2   Address                      649 non-null    object
#  3   Mother_Education             649 non-null    int64
#  4   Father_Education             649 non-null    int64
#  5   Mother_Job                   649 non-null    object
#  6   Travel_Time                  649 non-null    int64
#  7   Study_Time                   649 non-null    int64
#  8   Wants_Higher_Education       649 non-null    object
#  9   Internet_Access              649 non-null    object
#  10  In_Relationship              649 non-null    object
#  11  Free_Time                    649 non-null    int64
#  12  Going_Out                    649 non-null    int64
# ...

# %%
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# 1                 1    at_home      other  ...         3         3
# 2                 1    at_home      other  ...         3         2
# 3                 2     health   services  ...         2         2
# 4                 3      other      other  ...         3         2
#
#    Weekend_Alcohol_Consumption  Weekday_Alcohol_Consumption  Health_Status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
colunas_uteis = [
    'Gender',
    'Age',
    'Address',
    'Mother_Education',
    'Father_Education',
    'Mother_Job',
    'Travel_Time',
    'Study_Time',
    'Wants_Higher_Education',
    'Internet_Access',
    'In_Relationship',
    'Free_Time',
    'Going_Out',
    'Weekend_Alcohol_Consumption',
    'Weekday_Alcohol_Consumption',
    'Number_of_Absences',
    'Grade_1',
    'Grade_2',
    'Final_Grade',
    'Dropped_Out'
]

df_limpo = df[colunas_uteis]

# %%
df_limpo.head
# Out:
# <bound method NDFrame.head of     Gender  Age Address  Mother_Education  Father_Education Mother_Job  \
# 0        F   18       U                 4                 4    at_home
# 1        F   17       U                 1                 1    at_home
# 2        F   15       U                 1                 1    at_home
# 3        F   15       U                 4                 2     health
# 4        F   16       U                 3                 3      other
# ..     ...  ...     ...               ...               ...        ...
# 644      F   19       R                 2                 3   services
# 645      F   18       U                 3                 1    teacher
# 646      F   18       U                 1                 1      other
# 647      M   17       U                 3                 1   services
# 648      M   18       R                 3                 2   services
#
#      Travel_Time  Study_Time Wants_Higher_Education Internet_Access  \
# ...

# %%
df_limpo.to_csv('../dados/dados_evasao_limpo.csv', index=False)

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\oizab\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
